# %% [markdown]
# # Audio Compression with Deep Learning - Quick Start
#
# This notebook demonstrates how to use the audio compression models for research and experimentation.
#
# ## PRIVACY DISCLAIMER
#
# **This is a research demonstration tool for educational purposes only.**
# - No personal data is stored or transmitted
# - Misuse for malicious purposes (voice cloning, deepfakes) is prohibited
# - Use responsibly and in accordance with applicable laws
